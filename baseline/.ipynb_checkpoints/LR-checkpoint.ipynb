# %%
from gurobipy import *
import pandas as pd
import numpy as np
import os

# display settings
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %% [markdown]
# ## Set mode

# %%
# mode = "train"
mode = "testcase"

# %% [markdown]
# ## Set working directory

# %%
print(os.getcwd())

if mode == "train":
    if (os.getcwd() == "/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/to students/data"):
        pass
    else:
        os.chdir("/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/to students/data")
else:
    if (os.getcwd() == "/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/testcase/testcases"):
        pass
    else:
        os.chdir("/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/testcase/testcases")

print(os.getcwd())
os.listdir()
# Out:
# /Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/baseline
# /Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/testcase/testcases
# ['instance 345.csv',
#  'instance 351.csv',
#  'instance 184.csv',
#  'instance 190.csv',
#  'instance 14.csv',
#  'instance 28.csv',
#  'instance 147.csv',
#  'instance 153.csv',
#  'instance 9.csv',
#  'instance 219.csv',
#  'instance 231.csv',
#  'instance 225.csv',
#  'instance 224.csv',
#  'instance 230.csv',
#  'instance 218.csv',
#  'instance 8.csv',
#  'instance 152.csv',
#  'instance 29.csv',
#  'instance 146.csv',
#  'instance 15.csv',
#  'instance 191.csv',
#  'instance 185.csv',
#  'instance 350.csv',
#  'instance 344.csv',
#  'instance 352.csv',
#  'instance 346.csv',
#  'instance 193.csv',
#  'instance 187.csv',
#  'instance 178.csv',
#  'instance 17.csv',
#  'instance 150.csv',
#  'instance 144.csv',
#  'instance 226.csv',
#  'instance 232.csv',
#  'instance 233.csv',
#  'instance 227.csv',
#  'instance 145.csv',
#  'instance 151.csv',
#  'instance 179.csv',
#  'instance 16.csv',
#  'instance 186.csv',
#  'instance 192.csv',
#  'instance 347.csv',
#  'instance 353.csv',
#  'instance 343.csv',
#  'instance 196.csv',
#  'instance 182.csv',
#  'instance 155.csv',
#  'instance 141.csv',
#  'instance 169.csv',
#  'instance 12.csv',
#  '.DS_Store',
#  'instance 223.csv',
#  'instance 237.csv',
#  'instance 236.csv',
#  'instance 222.csv',
#  'instance 13.csv',
#  'instance 168.csv',
#  'instance 140.csv',
#  'instance 154.csv',
#  'instance 183.csv',
#  'instance 197.csv',
#  'instance 342.csv',
#  'instance 340.csv',
#  'instance 354.csv',
#  'instance 181.csv',
#  'instance 195.csv',
#  'instance 142.csv',
#  'instance 39.csv',
#  'instance 156.csv',
#  'instance 11.csv',
#  'instance 234.csv',
#  'instance 220.csv',
#  'instance 208.csv',
#  'instance 209.csv',
#  'instance 221.csv',
#  'instance 235.csv',
#  'instance 10.csv',
#  'instance 38.csv',
#  'instance 157.csv',
#  'instance 143.csv',
#  'instance 194.csv',
#  'instance 180.csv',
#  'instance 341.csv',
#  'instance 326.csv',
#  'instance 332.csv',
#  'instance 88.csv',
#  'instance 118.csv',
#  'instance 77.csv',
#  'instance 63.csv',
#  'instance 124.csv',
#  'instance 130.csv',
#  'instance 291.csv',
#  'instance 285.csv',
#  'instance 252.csv',
#  'instance 246.csv',
#  'instance 247.csv',
#  'instance 253.csv',
#  'instance 284.csv',
#  'instance 290.csv',
#  'instance 131.csv',
#  'instance 125.csv',
#  'instance 62.csv',
#  'instance 119.csv',
#  'instance 76.csv',
#  'instance 89.csv',
#  'instance 333.csv',
#  'instance 327.csv',
#  'instance 319.csv',
#  'instance 331.csv',
#  'instance 325.csv',
#  'instance 60.csv',
#  'instance 74.csv',
#  'instance 133.csv',
#  'instance 48.csv',
#  'instance 127.csv',
#  'instance 286.csv',
#  'instance 292.csv',
#  'instance 279.csv',
#  'instance 245.csv',
#  'instance 251.csv',
#  'instance 250.csv',
#  'instance 244.csv',
#  'instance 278.csv',
#  'instance 293.csv',
#  'instance 287.csv',
#  'instance 49.csv',
#  'instance 126.csv',
#  'instance 132.csv',
#  'instance 75.csv',
#  'instance 61.csv',
#  'instance 324.csv',
#  'instance 330.csv',
#  'instance 318.csv',
#  'instance 334.csv',
#  'instance 320.csv',
#  'instance 308.csv',
#  'instance 59.csv',
#  'instance 136.csv',
#  'instance 122.csv',
#  'instance 65.csv',
#  'instance 71.csv',
#  'instance 283.csv',
#  'instance 297.csv',
#  'instance 240.csv',
#  'instance 254.csv',
#  'instance 268.csv',
#  'instance 269.csv',
#  'instance 255.csv',
#  'instance 241.csv',
#  'instance 296.csv',
#  'instance 282.csv',
#  'instance 70.csv',
#  'instance 64.csv',
#  'instance 123.csv',
#  'instance 58.csv',
#  'instance 137.csv',
#  'instance 309.csv',
#  'instance 321.csv',
#  'instance 335.csv',
#  'instance 323.csv',
#  'instance 337.csv',
#  'instance 99.csv',
#  'instance 121.csv',
#  'instance 135.csv',
#  'instance 72.csv',
#  'instance 109.csv',
#  'instance 66.csv',
#  'instance 294.csv',
#  'instance 280.csv',
#  'instance 257.csv',
#  'instance 243.csv',
#  'instance 242.csv',
#  'instance 256.csv',
#  'instance 281.csv',
#  'instance 295.csv',
#  'instance 108.csv',
#  'instance 67.csv',
#  'instance 73.csv',
#  'instance 134.csv',
#  'instance 120.csv',
#  'instance 98.csv',
#  'instance 336.csv',
#  'instance 322.csv',
#  'instance 307.csv',
#  'instance 313.csv',
#  'instance 95.csv',
#  'instance 81.csv',
#  'instance 139.csv',
#  'instance 56.csv',
#  'instance 42.csv',
#  'instance 105.csv',
#  'instance 111.csv',
#  'instance 298.csv',
#  'instance 273.csv',
#  'instance 267.csv',
#  'instance 266.csv',
#  'instance 272.csv',
#  'instance 299.csv',
#  'instance 110.csv',
#  'instance 104.csv',
#  'instance 43.csv',
#  'instance 138.csv',
#  'instance 57.csv',
#  'instance 80.csv',
#  'instance 94.csv',
#  'instance 312.csv',
#  'instance 306.csv',
#  'instance 338.csv',
#  'instance 310.csv',
#  'instance 304.csv',
#  'instance 82.csv',
#  'instance 96.csv',
#  'instance 41.csv',
#  'instance 55.csv',
#  'instance 112.csv',
#  'instance 69.csv',
#  'instance 106.csv',
#  'instance 258.csv',
#  'instance 264.csv',
#  'instance 270.csv',
#  'instance 271.csv',
#  'instance 265.csv',
#  'instance 259.csv',
#  'instance 68.csv',
#  'instance 107.csv',
#  'instance 113.csv',
#  'instance 54.csv',
#  'instance 40.csv',
#  'instance 97.csv',
#  'instance 83.csv',
#  'instance 305.csv',
#  'instance 311.csv',
#  'instance 339.csv',
#  'instance 315.csv',
#  'instance 301.csv',
#  'instance 329.csv',
#  'instance 87.csv',
#  'instance 93.csv',
#  'instance 78.csv',
#  'instance 117.csv',
#  'instance 103.csv',
#  'instance 44.csv',
#  'instance 50.csv',
#  'instance 261.csv',
#  'instance 275.csv',
#  'instance 249.csv',
#  'instance 248.csv',
#  'instance 274.csv',
#  'instance 260.csv',
#  'instance 51.csv',
#  'instance 45.csv',
#  'instance 102.csv',
#  'instance 79.csv',
#  'instance 116.csv',
#  'instance 92.csv',
#  'instance 86.csv',
#  'instance 328.csv',
#  'instance 300.csv',
#  'instance 314.csv',
#  'instance 302.csv',
#  'instance 316.csv',
#  'instance 90.csv',
#  'instance 84.csv',
#  'instance 100.csv',
#  'instance 114.csv',
#  'instance 53.csv',
#  'instance 128.csv',
#  'instance 47.csv',
#  'instance 289.csv',
#  'instance 276.csv',
#  'instance 262.csv',
#  'instance 263.csv',
#  'instance 277.csv',
#  'instance 288.csv',
#  'instance 129.csv',
#  'instance 46.csv',
#  'instance 52.csv',
#  'instance 115.csv',
#  'instance 101.csv',
#  'instance 85.csv',
#  'instance 91.csv',
#  'instance 317.csv',
#  'instance 303.csv',
#  'instance 199.csv',
#  'instance 35.csv',
#  'instance 21.csv',
#  'instance 166.csv',
#  'instance 172.csv',
#  'instance 238.csv',
#  'instance 210.csv',
#  'instance 204.csv',
#  'instance 205.csv',
#  'instance 211.csv',
#  'instance 239.csv',
#  'instance 1.csv',
#  'instance 173.csv',
#  'instance 167.csv',
#  'instance 20.csv',
#  'instance 34.csv',
#  'instance 198.csv',
#  'instance 22.csv',
#  'instance 159.csv',
#  'instance 36.csv',
#  'instance 171.csv',
#  'instance 165.csv',
#  'instance 3.csv',
#  'instance 207.csv',
#  'instance 213.csv',
#  'instance 212.csv',
#  'instance 206.csv',
#  'instance 2.csv',
#  'instance 164.csv',
#  'instance 170.csv',
#  'instance 158.csv',
#  'instance 37.csv',
#  'instance 23.csv',
#  'instance 174.csv',
#  'instance 160.csv',
#  'instance 148.csv',
#  'instance 27.csv',
#  'instance 33.csv',
#  'instance 6.csv',
#  'instance 202.csv',
#  'instance 216.csv',
#  'instance 217.csv',
#  'instance 203.csv',
#  'instance 7.csv',
#  'instance 32.csv',
#  'instance 149.csv',
#  'instance 26.csv',
#  'instance 161.csv',
#  'instance 175.csv',
#  'instance 349.csv',
#  'instance 188.csv',
#  'instance 163.csv',
#  'instance 18.csv',
#  'instance 177.csv',
#  'instance 30.csv',
#  'instance 24.csv',
#  'instance 5.csv',
#  'instance 215.csv',
#  'instance 201.csv',
#  'instance 229.csv',
#  'instance 228.csv',
#  'instance 200.csv',
#  'instance 214.csv',
#  'instance 4.csv',
#  'instance 25.csv',
#  'instance 31.csv',
#  'instance 19.csv',
#  'instance 176.csv',
#  'instance 162.csv',
#  'instance 189.csv',
#  'instance 348.csv']

# %% [markdown]
# ## Defining Functions

# %%
def split_(row, machine_set):
    if row is np.nan:
        return list(machine_set)
    else:
        return list(map(int, row.split(",")))

# %%
def file_preprocess(file_path):
    ''' read csv and create usable dataframe'''
    
    # get machine set
    df = pd.read_csv(file_path, index_col=0)
    mfor1 = df['Stage-1 Machines'].values
    mfor2 = df['Stage-2 Machines'].values
    mfor1 = [list(map(int, x.split(','))) for x in mfor1]
    mfor2 = [list(map(int, x.split(','))) for x in mfor2 if x is not np.nan]
    mfor1 = [item for sublist in mfor1 for item in sublist]
    mfor2 = [item for sublist in mfor2 for item in sublist]
    machine_set_ = list(set(mfor1 + mfor2))
    
    # turn strings into list in dataframe
    df["Stage-1 Machines"] = df["Stage-1 Machines"].apply(split_, machine_set=machine_set_)
    df["Stage-2 Machines"] = df["Stage-2 Machines"].apply(split_, machine_set=machine_set_)
    
    from sklearn.preprocessing import MultiLabelBinarizer
    stage1 = df["Stage-1 Machines"]
    stage2 = df["Stage-2 Machines"]

    # create stage machine dummy variables from list
    mlb = MultiLabelBinarizer()
    mlb2 = MultiLabelBinarizer()
    dummyM1_df = pd.DataFrame(mlb.fit_transform(stage1), columns=mlb.classes_, index=df.index)
    dummyM1_df = dummyM1_df.add_prefix("stage1_m")
    dummyM2_df = pd.DataFrame(mlb2.fit_transform(stage2), columns=mlb2.classes_, index=df.index)
    dummyM2_df = dummyM2_df.add_prefix("stage2_m")
    dummyM1_df, dummyM2_df
    
    # dummy column names
    dummyM1_col = dummyM1_df.columns
    dummyM2_col = dummyM2_df.columns

    df = df.join(dummyM1_df, on="Job ID")
    df = df.join(dummyM2_df, on="Job ID")
    df = df.drop(["Stage-1 Machines", "Stage-2 Machines"], axis=1)
    
    return df, machine_set_, dummyM1_col, dummyM2_col

# %%
def IP(instance, machine_set, dummyM1_col, dummyM2_col, time_limit1, time_limit2):
    ''' two stage optimization'''
    
    # turn data into corresponding list
    pt_stage1 = instance["Stage-1 Processing Time"].values
    pt_stage2 = instance["Stage-2 Processing Time"].values
    due_time = instance["Due Time"].values

    job_id = list(instance.index)
    m_dummy_stage1 = instance[dummyM1_col].values
    m_dummy_stage2 = instance[dummyM2_col].values
    
    # L: big number
    L = (sum(pt_stage1) + sum(pt_stage2)) * 100
    
    ''' stage 1 '''
    p1 = Model("p1")
    p1.setParam('TimeLimit', time_limit1)
    j_num = int(len(job_id))
    m_len = len(machine_set)

    # Variables
    s_jkm = []
    c_jkm = []
    x_jkm = []
    for j in range(j_num):
        tmp_s = []
        tmp_c = []
        tmp_x = []
        for k in range(2):
            tmp_s.append([])
            tmp_c.append([])
            tmp_x.append([])
            for m in machine_set:
                tmp_s[k].append(p1.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "s_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_c[k].append(p1.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_x[k].append(p1.addVar(lb = 0, vtype = GRB.BINARY, name = "x_" + str(j + 1) + "," + str(k) + ","+ str(m)))  
        s_jkm.append(tmp_s)
        c_jkm.append(tmp_c)
        x_jkm.append(tmp_x)

    y_jkjkm = []
    for j1 in range(j_num):
        y_jkjkm.append([])
        for k1 in range(2):
            y_jkjkm[j1].append([])
            for j2 in range(j1 + 1, j_num):
                y_jkjkm[j1][k1].append([])
                for k2 in range(2):
                    y_jkjkm[j1][k1][j2 - j1 - 1].append([])
                    for m in machine_set:
                        y_jkjkm[j1][k1][j2 - j1 - 1][k2].append(p1.addVar(lb = 0, vtype = GRB.BINARY, 
                                                       name = "y_" + str(j1 + 1) + "," + str(k1 + 1) + "," + str(j2 + 1) + "," + str(k2 + 1)+ "," + str(m)))

    c_j = []
    for j in range(j_num):
        c_j.append(p1.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1)))
    t_j = []
    for j in range(j_num):
        t_j.append(p1.addVar(lb = 0, vtype = GRB.BINARY, name = "t_" + str(j + 1)))
        
    # setting the objective function 
    p1.setObjective(quicksum(t_j[j] for j in range(j_num)), GRB.MINIMIZE) 
    
    # add constraints
    # job stage 1 machine limit
    p1.addConstrs((x_jkm[j][0][m] <= m_dummy_stage1[j][m] for j in range(j_num) for m in range(m_len)))
    # job stage 2 machine limit
    p1.addConstrs((x_jkm[j][1][m] <= m_dummy_stage2[j][m] for j in range(j_num) for m in range(m_len)))

    # tardy variable
    p1.addConstrs((t_j[j] * L >= c_j[j] - due_time[j] 
                    for j in range(j_num)), "tardy count")

    # job complete time
    p1.addConstrs((c_j[j] >= quicksum(c_jkm[j][1][m] for m in range(m_len))
                    for j in range(j_num)), "job completion time")

    # each job assigned once
    p1.addConstrs((quicksum(x_jkm[j][k][m] for m in range(m_len)) == 1 for j in range(j_num) for k in range(2)), "job assignment constraint")

    p1.addConstrs((s_jkm[j][k][m] + c_jkm[j][k][m] <= x_jkm[j][k][m] * L for j in range(j_num) for k in range(2) for m in range(m_len)))

    # process time
    p1.addConstrs((c_jkm[j][0][m] >= s_jkm[j][0][m] + pt_stage1[j] - (1 - x_jkm[j][0][m]) * L for j in range(j_num) for m in range(m_len)))
    p1.addConstrs((c_jkm[j][1][m] >= s_jkm[j][1][m] + pt_stage2[j] - (1 - x_jkm[j][1][m]) * L for j in range(j_num) for m in range(m_len)))

    for m in range(m_len):
        for j1 in range(j_num):
            for k1 in range(2):
                for j2 in range(j_num - j1 - 1):
                    for k2 in range(2):
                    # 注意ijm的indexing方法不同
                        p1.addConstr(s_jkm[j1][k1][m] >= c_jkm[j1 + j2 + 1][k2][m] - y_jkjkm[j1][k1][j2][k2][m] * L)
                        p1.addConstr(s_jkm[j1 + j2 + 1][k2][m] >= c_jkm[j1][k1][m] - (1 - y_jkjkm[j1][k1][j2][k2][m]) * L)

    # subjob 2 starts only after subjob 1
    p1.addConstrs((quicksum(s_jkm[j][1][m] for m in range(m_len)) >= quicksum(c_jkm[j][0][m] for m in range(m_len)) for j in range(j_num)), "subjob 1 ends before subjob2 starts")

    p1.optimize()
    
    
    ''' stage 2 '''
    p1_2 = Model("p1_2")
    
    # set time limit
    p1_2.setParam('TimeLimit', time_limit2)
    j_num = int(len(job_id))
    m_len = len(machine_set)

    # tardy job num result from part 1
    T = p1.objVal

    # Variables
    u = p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "u")
    s_jkm = []
    c_jkm = []
    x_jkm = []
    for j in range(j_num):
        tmp_s = []
        tmp_c = []
        tmp_x = []
        for k in range(2):
            tmp_s.append([])
            tmp_c.append([])
            tmp_x.append([])
            for m in machine_set:
                tmp_s[k].append(p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "s_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_c[k].append(p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_x[k].append(p1_2.addVar(lb = 0, vtype = GRB.BINARY, name = "x_" + str(j + 1) + "," + str(k) + ","+ str(m)))  
        s_jkm.append(tmp_s)
        c_jkm.append(tmp_c)
        x_jkm.append(tmp_x)
    print(len(x_jkm))
    print(len(x_jkm[0]))
    print(len(x_jkm[0][0]))

    y_jkjkm = []
    for j1 in range(j_num):
        y_jkjkm.append([])
        for k1 in range(2):
            y_jkjkm[j1].append([])
            for j2 in range(j1 + 1, j_num):
                y_jkjkm[j1][k1].append([])
                for k2 in range(2):
                    y_jkjkm[j1][k1][j2 - j1 - 1].append([])
                    for m in machine_set:
                        y_jkjkm[j1][k1][j2 - j1 - 1][k2].append(p1_2.addVar(lb = 0, vtype = GRB.BINARY, 
                                                       name = "y_" + str(j1 + 1) + "," + str(k1 + 1) + "," + str(j2 + 1) + "," + str(k2 + 1)+ "," + str(m)))

    c_j = []
    for j in range(j_num):
        c_j.append(p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1)))
    t_j = []
    for j in range(j_num):
        t_j.append(p1_2.addVar(lb = 0, vtype = GRB.BINARY, name = "t_" + str(j + 1)))
        
        
    # setting the objective function 
    p1_2.setObjective(u, GRB.MINIMIZE) 
    
    
    # add constraints and name them
    # makespan
    p1_2.addConstrs((u >= c_j[j] for j in range(j_num)))
    
    # tardy jobs num set to "lesser than or equal to" T
    p1_2.addConstr((quicksum(t_j[j] for j in range(j_num)) <= T))

    # stage 1 machine limit
    p1_2.addConstrs((x_jkm[j][0][m] <= m_dummy_stage1[j][m] for j in range(j_num) for m in range(m_len)))
    # stage 2 machine limit
    p1_2.addConstrs((x_jkm[j][1][m] <= m_dummy_stage2[j][m] for j in range(j_num) for m in range(m_len)))

    # tardy variable
    p1_2.addConstrs((t_j[j] * L >= c_j[j] - due_time[j] 
                    for j in range(j_num)), "tardy count")

    # job complete time
    p1_2.addConstrs((c_j[j] >= quicksum(c_jkm[j][1][m] for m in range(m_len))
                    for j in range(j_num)), "job completion time")

    # each job assigned once
    p1_2.addConstrs((quicksum(x_jkm[j][k][m] for m in range(m_len)) == 1 for j in range(j_num) for k in range(2)), "job assignment constraint")

    p1_2.addConstrs((s_jkm[j][k][m] + c_jkm[j][k][m] <= x_jkm[j][k][m] * L for j in range(j_num) for k in range(2) for m in range(m_len)))

    # process time
    p1_2.addConstrs((c_jkm[j][0][m] >= s_jkm[j][0][m] + pt_stage1[j] - (1 - x_jkm[j][0][m]) * L for j in range(j_num) for m in range(m_len)))
    p1_2.addConstrs((c_jkm[j][1][m] >= s_jkm[j][1][m] + pt_stage2[j] - (1 - x_jkm[j][1][m]) * L for j in range(j_num) for m in range(m_len)))

    for m in range(m_len):
        for j1 in range(j_num):
            for k1 in range(2):
                for j2 in range(j_num - j1 - 1):
                    for k2 in range(2):
                    # 注意ijm的indexing方法不同
                        p1_2.addConstr(s_jkm[j1][k1][m] >= c_jkm[j1 + j2 + 1][k2][m] - y_jkjkm[j1][k1][j2][k2][m] * L)
                        p1_2.addConstr(s_jkm[j1 + j2 + 1][k2][m] >= c_jkm[j1][k1][m] - (1 - y_jkjkm[j1][k1][j2][k2][m]) * L)

    # subjob 2 starts only after subjob 1
    p1_2.addConstrs((quicksum(s_jkm[j][1][m] for m in range(m_len)) >= quicksum(c_jkm[j][0][m] for m in range(m_len)) for j in range(j_num)), "subjob 1 ends before subjob2 starts")
    p1_2.optimize()
    
    
    return p1.objVal, p1_2.objVal

# %% [markdown]
# ## Set instances and test

# %%
# set instances to test
path_list = ["instance 1.csv", "instance 2.csv", "instance 3.csv", "instance 4.csv", "instance 5.csv"]
# path_list = ["instance 5.csv"]

# %%
tardy_list = []
makespan_list = []

for path in path_list:
    df, machine_set, dummyM1_col, dummyM2_col = file_preprocess(path)
    tardy, makespan = IP(df, machine_set, dummyM1_col, dummyM2_col, 60, 180)
    tardy_list.append(tardy)
    makespan_list.append(makespan)

for i in range(len(path_list)):
    print("----------------")
    print("file:", path_list[i])
    print("number of tardy jobs:", tardy_list[i])
    print("makespan:", makespan_list[i])
    print("----------------")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-05-24
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 9375 rows, 5130 columns and 28095 nonzeros
# Model fingerprint: 0x6a9a2da8
# Variable types: 615 continuous, 4515 integer (4515 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2729 rows and 1337 columns
# Presolve time: 0.04s
# Presolved: 6646 rows, 3793 columns, 20121 nonzeros
# Variable types: 476 continuous, 3317 integer (3317 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 5.664488e-04, 850 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00057    0   24   14.00000    0.00057   100%     -    0s
#      0     0    2.00009    0   45   14.00000    2.00009  85.7%     -    0s
# H    0     0                       3.0000000    2.00009  33.3%     -    0s
#      0     0    3.00000    0   49    3.00000    3.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Flow cover: 10
#   RLT: 5
#
# Explored 1 nodes (2229 simplex iterations) in 0.16 seconds (0.19 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 3 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Set parameter TimeLimit to value 180
# 15
# 2
# 10
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 9391 rows, 5131 columns and 28140 nonzeros
# Model fingerprint: 0xc2220a52
# Variable types: 616 continuous, 4515 integer (4515 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2694 rows and 1302 columns
# Presolve time: 0.03s
# Presolved: 6697 rows, 3829 columns, 20334 nonzeros
# Variable types: 512 continuous, 3317 integer (3317 binary)
#
# Root relaxation: objective 1.680000e+01, 1325 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.80000    0   31          -   16.80000      -     -    0s
#      0     0   16.80000    0   31          -   16.80000      -     -    0s
#      0     0   16.80000    0   32          -   16.80000      -     -    0s
#      0     0   16.80000    0   37          -   16.80000      -     -    0s
#      0     0   16.80000    0   34          -   16.80000      -     -    0s
# H    0     0                      26.0000000   16.80000  35.4%     -    0s
# H    0     0                      20.4000000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   18   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   18   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   23   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   21   20.40000   16.80000  17.6%     -    0s
# H    0     0                      19.7000000   16.80000  14.7%     -    0s
#      0     0   16.80000    0    7   19.70000   16.80000  14.7%     -    0s
# H    0     0                      18.7000000   16.80000  10.2%     -    0s
#      0     0   16.80000    0    8   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   10   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   12   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   12   18.70000   16.80000  10.2%     -    0s
#      0     2   16.80000    0   10   18.70000   16.80000  10.2%     -    0s
# H   44    42                      18.5000000   16.80000  9.19%  40.4    1s
# H  213   255                      18.2000000   16.80000  7.69%  21.3    1s
# H  601   511                      18.0000000   16.80000  6.67%  15.8    1s
# H  884   831                      17.9000000   16.80000  6.15%  14.9    1s
# * 1311   831              92      17.7000000   16.80000  5.08%  14.3    1s
# H 1313   831                      17.0000000   16.80000  1.18%  14.3    1s
# H 1586   701                      16.8000000   16.80000  0.00%  13.9    1s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 4
#   Implied bound: 43
#   MIR: 9
#   Flow cover: 99
#   Inf proof: 3
#   RLT: 16
#   Relax-and-lift: 3
#
# Explored 1963 nodes (43360 simplex iterations) in 1.78 seconds (1.83 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 16.8 17 17.7 ... 20.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.680000000000e+01, best bound 1.680000000000e+01, gap 0.0000%
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 255407 rows, 130784 columns and 766526 nonzeros
# Model fingerprint: 0x91304890
# Variable types: 4209 continuous, 126575 integer (126575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 50583 rows and 24884 columns
# Presolve time: 1.78s
# Presolved: 204824 rows, 105900 columns, 616423 nonzeros
# Variable types: 3461 continuous, 102439 integer (102439 binary)
# Found heuristic solution: objective 60.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 1222 rows and 287 columns
# Root relaxation presolved: 203602 rows, 106548 columns, 613979 nonzeros
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 4.970499e-04, 9555 iterations, 0.89 seconds (0.92 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00050    0 6199   60.00000    0.00050   100%     -    7s
#      0     0    3.00046    0 2783   60.00000    3.00046  95.0%     -   13s
#      0     0    5.00022    0 1505   60.00000    5.00022  91.7%     -   16s
#      0     0    5.00027    0 1457   60.00000    5.00027  91.7%     -   16s
#      0     0    5.00027    0 2076   60.00000    5.00027  91.7%     -   21s
#      0     0    5.00028    0 2119   60.00000    5.00028  91.7%     -   29s
#      0     0    5.00028    0 1910   60.00000    5.00028  91.7%     -   58s
#      0     0          -    0        60.00000    5.00028  91.7%     -   60s
#
# Cutting planes:
#   Cover: 552
#   Implied bound: 1
#   MIR: 7
#   Flow cover: 478
#   GUB cover: 1
#   Zero half: 2
#   Network: 3
#   RLT: 418
#
# Explored 1 nodes (138787 simplex iterations) in 60.02 seconds (302.53 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 60
#
# Time limit reached
# Best objective 6.000000000000e+01, best bound 6.000000000000e+00, gap 90.0000%
# Set parameter TimeLimit to value 180
# 61
# 2
# 17
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 255469 rows, 130785 columns and 766709 nonzeros
# Model fingerprint: 0x7ee113d2
# Variable types: 4210 continuous, 126575 integer (126575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 50335 rows and 24636 columns
# Presolve time: 1.45s
# Presolved: 205134 rows, 106149 columns, 617889 nonzeros
# Variable types: 3710 continuous, 102439 integer (102439 binary)
# Found heuristic solution: objective 318.4000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 248 rows and 237 columns
# Root relaxation presolved: 204886 rows, 105912 columns, 617041 nonzeros
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.08s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 1.840000e+01, 7623 iterations, 1.03 seconds (1.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.40000    0 15206  318.40000   18.40000  94.2%     -    9s
# H    0     0                     158.1000000   18.40000  88.4%     -   10s
#      0     0   18.40000    0 2535  158.10000   18.40000  88.4%     -   25s
#      0     0   18.40000    0 1807  158.10000   18.40000  88.4%     -   32s
#      0     0   18.40000    0 2674  158.10000   18.40000  88.4%     -   49s
#      0     0   18.40000    0 1916  158.10000   18.40000  88.4%     -   61s
#      0     0   18.40000    0 2361  158.10000   18.40000  88.4%     -   89s
# H    0     0                      88.5000000   18.40000  79.2%     -   90s
# H    0     0                      78.4000000   18.40000  76.5%     -   92s
#      0     0   18.40000    0 2331   78.40000   18.40000  76.5%     -  104s
#      0     0   18.40000    0  357   78.40000   18.40000  76.5%     -  127s
#      0     0   18.40000    0  524   78.40000   18.40000  76.5%     -  129s
#      0     0   18.40000    0  547   78.40000   18.40000  76.5%     -  131s
#      0     0   18.40000    0  547   78.40000   18.40000  76.5%     -  133s
# H    0     0                      65.4000000   18.40000  71.9%     -  134s
# H    0     0                      65.3000000   18.40000  71.8%     -  137s
#      0     2   18.40000    0  547   65.30000   18.40000  71.8%     -  145s
# H    7    16                      60.0000000   18.40000  69.3%  5621  146s
# H   35    46                      51.4000000   18.40000  64.2%  2925  150s
# H   42    46                      49.4000000   18.40000  62.8%  2521  150s
# H   75   124                      46.8000000   18.40000  60.7%  1454  156s
# H   96   124                      46.0000000   18.40000  60.0%  1152  156s
#    123   344   18.40000   11  276   46.00000   18.40000  60.0%   915  162s
# H  144   344                      46.0000000   18.40000  60.0%   791  162s
# H  166   344                      44.5000000   18.40000  58.7%   691  162s
#    343  1036   18.40000   29  186   44.50000   18.40000  58.7%   354  173s
# H  882  1036                      41.4000000   18.40000  55.6%   156  173s
# H 1060  1430                      41.3000000   18.40000  55.4%   132  180s
# H 1090  1430                      41.1000000   18.40000  55.2%   129  180s
#
# Cutting planes:
#   Cover: 1730
#   Implied bound: 391
#   MIR: 94
#   Flow cover: 4495
#   Network: 6
#   RLT: 2883
#   Relax-and-lift: 393
#   PSD: 11
#
# Explored 1478 nodes (458812 simplex iterations) in 180.33 seconds (590.40 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 41.1 41.3 41.4 ... 60
#
# Time limit reached
# Best objective 4.109999999999e+01, best bound 1.840000000000e+01, gap 55.2311%
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 15950 rows, 8492 columns and 47762 nonzeros
# Model fingerprint: 0x4e722549
# Variable types: 726 continuous, 7766 integer (7766 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 1652 rows and 715 columns
# Presolve time: 0.08s
# Presolved: 14298 rows, 7777 columns, 43155 nonzeros
# Variable types: 636 continuous, 7141 integer (7141 binary)
# Found heuristic solution: objective 21.0000000
#
# Root relaxation: objective 5.001550e-01, 1402 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00007    0   70   21.00000    1.00007  95.2%     -    0s
#      0     0    3.00000    0   82   21.00000    3.00000  85.7%     -    0s
#      0     0    3.00000    0   79   21.00000    3.00000  85.7%     -    0s
#      0     0    3.00000    0   90   21.00000    3.00000  85.7%     -    0s
#      0     0    3.00000    0   84   21.00000    3.00000  85.7%     -    0s
# H    0     0                      19.0000000    3.00000  84.2%     -    0s
#      0     0    3.00000    0  115   19.00000    3.00000  84.2%     -    0s
# H    0     0                      13.0000000    3.00000  76.9%     -    0s
#      0     0    3.00000    0  100   13.00000    3.00000  76.9%     -    0s
#      0     0    3.00000    0   52   13.00000    3.00000  76.9%     -    1s
#      0     0    3.00000    0   56   13.00000    3.00000  76.9%     -    1s
# H    0     0                      12.0000000    3.00000  75.0%     -    1s
# H    0     0                      11.0000111    3.00000  72.7%     -    1s
#      0     0    3.00000    0   41   11.00001    3.00000  72.7%     -    1s
#      0     0    3.00000    0   42   11.00001    3.00000  72.7%     -    1s
# H    0     0                      11.0000000    3.00000  72.7%     -    1s
#      0     0    3.00000    0   63   11.00000    3.00000  72.7%     -    1s
#      0     0    3.00000    0   65   11.00000    3.00000  72.7%     -    1s
#      0     0    3.00000    0   77   11.00000    3.00000  72.7%     -    1s
#      0     0    3.00000    0   75   11.00000    3.00000  72.7%     -    1s
# H    0     0                      10.0000000    3.00000  70.0%     -    1s
#      0     0    3.00000    0   78   10.00000    3.00000  70.0%     -    1s
#      0     0    3.00000    0   77   10.00000    3.00000  70.0%     -    1s
#      0     2    3.00000    0   77   10.00000    3.00000  70.0%     -    2s
# H  182   189                       9.0000000    3.00000  66.7%  24.9    2s
# * 1824  1211             131       8.0000000    3.00000  62.5%  15.7    3s
#   2224  1305    4.00000   34   80    8.00000    3.00000  62.5%  15.7    5s
# H 3080  1682                       7.0000000    3.00000  57.1%  27.6    8s
#   3382  2229    5.00000   70   17    7.00000    3.00000  57.1%  27.0   10s
#  10511  5506    3.00020   47   36    7.00000    3.00000  57.1%  25.4   15s
#  17613 10401    6.00000   93   24    7.00000    3.00000  57.1%  24.9   20s
#  17656 16660    6.00000   94   25    7.00000    3.00000  57.1%  24.9   25s
#  34278 21728    6.00000  144   25    7.00000    3.00000  57.1%  25.4   37s
#  40671 25815    6.00001  146   23    7.00000    3.00000  57.1%  25.7   40s
#  50593 30681    6.00000  165   10    7.00000    3.00000  57.1%  25.9   46s
#  50698 36825 infeasible  166         7.00000    3.00000  57.1%  25.9   51s
#  65196 40193    6.00000  157   21    7.00000    3.00000  57.1%  25.9   55s
#  74643 44612    6.00000  163   18    7.00000    3.00000  57.1%  26.3   60s
#
# Cutting planes:
#   Cover: 9
#   MIR: 2
#   Flow cover: 83
#   Inf proof: 3
#   RLT: 9
#
# Explored 75286 nodes (1996845 simplex iterations) in 60.06 seconds (88.45 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 7 8 8 ... 12
#
# Time limit reached
# Best objective 7.000000000000e+00, best bound 3.000000000000e+00, gap 57.1429%
# Set parameter TimeLimit to value 180
# 22
# 2
# 8
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 15973 rows, 8493 columns and 47828 nonzeros
# Model fingerprint: 0xde814831
# Variable types: 727 continuous, 7766 integer (7766 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 1598 rows and 661 columns
# Presolve time: 0.07s
# Presolved: 14375 rows, 7832 columns, 43480 nonzeros
# Variable types: 691 continuous, 7141 integer (7141 binary)
#
# Root relaxation: objective 1.690000e+01, 2148 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.90000    0   44          -   16.90000      -     -    0s
#      0     0   16.90000    0   59          -   16.90000      -     -    0s
#      0     0   16.90000    0   40          -   16.90000      -     -    0s
#      0     0   16.90000    0   40          -   16.90000      -     -    0s
#      0     0   16.90000    0   61          -   16.90000      -     -    0s
#      0     0   16.90000    0   56          -   16.90000      -     -    0s
#      0     0   16.90000    0   47          -   16.90000      -     -    0s
#      0     0   16.90000    0   46          -   16.90000      -     -    0s
#      0     0   16.90000    0   46          -   16.90000      -     -    1s
#      0     0   16.90000    0   50          -   16.90000      -     -    1s
#      0     0   16.90000    0   44          -   16.90000      -     -    1s
#      0     0   16.90000    0   29          -   16.90000      -     -    1s
#      0     2   16.90000    0   29          -   16.90000      -     -    1s
#   1993  1203   22.70000   77   63          -   16.90000      -  19.1    5s
#   2774  2485   16.90000   46   81          -   16.90000      -  37.6   10s
#   8655  6133   22.20000  206   24          -   16.90000      -  39.4   15s
#  15710 11722   29.40000  177   12          -   16.90000      -  39.9   20s
#  23236 16454   30.20000  188   29          -   16.90000      -  41.3   25s
#  30428 21776 infeasible  149               -   16.90000      -  41.8   30s
#  33492 23404   16.90000  165   33          -   16.90000      -  42.7   37s
#  35627 24915   22.50000  149  107          -   16.90000      -  43.5   40s
# *38425 25792             159      32.7000000   16.90000  48.3%  45.0   41s
# H41449 27715                      32.7000000   16.90000  48.3%  44.9   43s
#  42686 28934   16.90000  164  104   32.70000   16.90000  48.3%  45.1   45s
# H47677 32312                      32.7000000   16.90000  48.3%  45.1   48s
#  48980 33017 infeasible  220        32.70000   16.90000  48.3%  44.9   50s
# H49005 31468                      30.5000000   16.90000  44.6%  44.9   50s
# H49433 29722                      28.7000000   16.90000  41.1%  44.9   50s
# H49901 29523                      28.0000000   16.90000  39.6%  44.8   51s
# H50948 29602                      27.5000000   16.90000  38.5%  44.7   52s
# H51143 28888                      27.1000000   16.90000  37.6%  44.6   52s
# H52018 29926                      27.0000000   16.90000  37.4%  44.6   54s
#  53914 30693   16.90000  115  142   27.00000   16.90000  37.4%  44.4   56s
#  59623 34562   16.90000  101   70   27.00000   16.90000  37.4%  44.5   61s
#  63645 36389   19.10000  114   54   27.00000   16.90000  37.4%  45.1   66s
# H64458 36389                      27.0000000   16.90000  37.4%  45.3   66s
#  67516 39252   19.90000  133   60   27.00000   16.90000  37.4%  45.9   71s
# H72306 35454                      25.8000000   16.90000  34.5%  46.5   74s
#  73599 35753 infeasible  135        25.80000   16.90000  34.5%  46.7   75s
# H73901 35753                      25.8000000   16.90000  34.5%  46.8   75s
# H76519 35208                      25.5000000   16.90000  33.7%  47.3   78s
# H76754 34365                      25.3000000   16.90000  33.2%  47.3   78s
#  77708 35154   16.90000  115   68   25.30000   16.90000  33.2%  47.3   80s
# H78077 35154                      25.3000000   16.90000  33.2%  47.4   80s
#  82400 36443   23.50000  122   56   25.30000   16.90000  33.2%  48.0   85s
#  85666 38062   21.40000  128   79   25.30000   16.90000  33.2%  48.6   90s
#  89837 39764   21.80000  120   22   25.30000   16.90000  33.2%  49.2   95s
#  93224 40692   23.80000  125   82   25.30000   16.90000  33.2%  49.7  100s
#  98322 42793   24.10000  121   83   25.30000   16.90000  33.2%  50.6  105s
# H99280 42793                      25.3000000   16.90000  33.2%  50.7  105s
#  103275 44484 infeasible  125        25.30000   16.90000  33.2%  51.2  111s
#  108541 46037   21.90000  121   20   25.30000   16.90000  33.2%  51.9  115s
#  114680 47962 infeasible  120        25.30000   16.90000  33.2%  52.5  121s
#  118813 49548   21.90000  118   29   25.30000   16.90000  33.2%  53.0  126s
#  121941 50524 infeasible  124        25.30000   16.90000  33.2%  53.5  130s
#  126916 51868 infeasible  123        25.30000   16.90000  33.2%  54.2  135s
#  131312 53254 infeasible  125        25.30000   16.90000  33.2%  54.7  140s
#  136046 54049   21.80000  119   60   25.30000   16.90000  33.2%  55.2  146s
#  136173 56948   22.40000  131   92   25.30000   16.90000  33.2%  55.2  155s
#  148861 58162   22.90000  122   57   25.30000   16.90000  33.2%  56.6  160s
#  152812 59729 infeasible  149        25.30000   16.90000  33.2%  57.0  165s
#  158873 62794   21.80000  112   44   25.30000   16.90000  33.2%  57.0  170s
#  162377 64864   18.80000  112   70   25.30000   16.90000  33.2%  57.0  175s
#  168815 67204 infeasible  135        25.30000   16.90000  33.2%  57.3  180s
#
# Cutting planes:
#   Cover: 50
#   Implied bound: 4
#   Flow cover: 24
#   RLT: 20
#
# Explored 169273 nodes (9748266 simplex iterations) in 180.03 seconds (270.65 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 25.3 25.3 25.3 ... 27.5
#
# Time limit reached
# Best objective 2.529999999474e+01, best bound 1.690000000000e+01, gap 33.2016%
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 270 rows, 212 columns and 812 nonzeros
# Model fingerprint: 0xf454dad6
# Variable types: 106 continuous, 106 integer (106 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Set parameter TimeLimit to value 180
# 2
# 2
# 13
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 273 rows, 213 columns and 818 nonzeros
# Model fingerprint: 0xa8b57f43
# Variable types: 107 continuous, 106 integer (106 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 9.4000001
# Presolve removed 57 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 216 rows, 209 columns, 704 nonzeros
# Variable types: 106 continuous, 103 integer (103 binary)
#
# Root relaxation: objective 9.400000e+00, 75 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.40000    0    3    9.40000    9.40000  0.00%     -    0s
#
# Explored 1 nodes (75 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 9.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.400000000000e+00, best bound 9.400000000000e+00, gap 0.0000%
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 93030 rows, 48132 columns and 279132 nonzeros
# Model fingerprint: 0x8c9ada22
# Variable types: 2226 continuous, 45906 integer (45906 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+04]
# Presolve removed 25254 rows and 12507 columns
# Presolve time: 0.39s
# Presolved: 67776 rows, 35625 columns, 204139 nonzeros
# Variable types: 1749 continuous, 33876 integer (33876 binary)
# Found heuristic solution: objective 41.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 269 rows and 139 columns
# Root relaxation presolved: 67507 rows, 35616 columns, 203601 nonzeros
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 5.090909e-04, 4842 iterations, 0.25 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.00020    0  175   41.00000    2.00020  95.1%     -    3s
#      0     0    8.00000    0  234   41.00000    8.00000  80.5%     -    4s
#      0     0    8.00000    0  256   41.00000    8.00000  80.5%     -    4s
# H    0     0                      33.0000000    8.00000  75.8%     -    5s
# H    0     0                      26.0000000    8.00000  69.2%     -    5s
#      0     0    8.00000    0  351   26.00000    8.00000  69.2%     -    5s
#      0     0    8.00000    0  300   26.00000    8.00000  69.2%     -    6s
# H    0     0                      25.0000000    8.00000  68.0%     -    6s
#      0     0    8.00000    0  388   25.00000    8.00000  68.0%     -    7s
#      0     0    8.00000    0  245   25.00000    8.00000  68.0%     -    7s
# H    0     0                      24.0000000    8.00000  66.7%     -    9s
# H    0     0                      23.0000000    8.00000  65.2%     -    9s
# H    0     0                      22.0000000    8.00000  63.6%     -    9s
#      0     0    8.00000    0  334   22.00000    8.00000  63.6%     -    9s
#      0     0    8.00000    0  306   22.00000    8.00000  63.6%     -   10s
# H    0     0                      21.0000000    8.00000  61.9%     -   12s
#      0     0    8.00000    0  285   21.00000    8.00000  61.9%     -   12s
#      0     0    8.00000    0  315   21.00000    8.00000  61.9%     -   13s
#      0     0    8.00000    0  307   21.00000    8.00000  61.9%     -   14s
#      0     0    8.00000    0  307   21.00000    8.00000  61.9%     -   15s
#      0     2    8.00000    0  174   21.00000    8.00000  61.9%     -   17s
#    307   266   12.00000   31   81   21.00000    8.00000  61.9%  83.3   20s
#   1691  1368   13.00003   92 1020   21.00000    8.00000  61.9%  34.1   28s
#   1693  1369    8.00000   17  779   21.00000    8.00000  61.9%  34.0   30s
#   1696  1371   11.00002   10  680   21.00000    8.00000  61.9%  34.0   35s
#   1699  1373   17.00000   74  601   21.00000    8.00000  61.9%  33.9   41s
#   1702  1376    8.00000   12  530   21.00000    8.00000  61.9%   125   50s
#   1705  1375    8.00009   14  595   21.00000    8.00009  61.9%   126   55s
#   1708  1380    9.00016   16  487   21.00000    8.00009  61.9%   126   60s
#
# Cutting planes:
#   Cover: 412
#   MIR: 13
#   Flow cover: 677
#   Zero half: 2
#   Network: 1
#   RLT: 295
#
# Explored 1712 nodes (298456 simplex iterations) in 60.30 seconds (153.43 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 9: 21 22 23 ... 41
#
# Time limit reached
# Best objective 2.100000000000e+01, best bound 9.000000000000e+00, gap 57.1429%
# Set parameter TimeLimit to value 180
# 42
# 2
# 13
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 93073 rows, 48133 columns and 279258 nonzeros
# Model fingerprint: 0xd40f691d
# Variable types: 2227 continuous, 45906 integer (45906 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+04]
# Presolve removed 25147 rows and 12400 columns
# Presolve time: 0.38s
# Presolved: 67926 rows, 35733 columns, 204840 nonzeros
# Variable types: 1857 continuous, 33876 integer (33876 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 67 rows and 67 columns
# Root relaxation presolved: 67859 rows, 35666 columns, 204706 nonzeros
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex (primal model)
#
# Root relaxation: objective 1.760000e+01, 5748 iterations, 0.21 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.60000    0 1741          -   17.60000      -     -    4s
#      0     0   17.60000    0 1322          -   17.60000      -     -    6s
#      0     0   17.60000    0 1179          -   17.60000      -     -    7s
#      0     0   17.60000    0  189          -   17.60000      -     -   20s
#      0     0   17.60000    0  249          -   17.60000      -     -   21s
#      0     0   17.60000    0  363          -   17.60000      -     -   24s
#      0     0   17.60000    0  343          -   17.60000      -     -   25s
#      0     0   17.60000    0  327          -   17.60000      -     -   26s
#      0     0   17.60000    0  326          -   17.60000      -     -   26s
#      0     0   17.60000    0  141          -   17.60000      -     -   29s
#      0     0   17.60000    0  175          -   17.60000      -     -   29s
#      0     0   17.60000    0  113          -   17.60000      -     -   31s
#      0     0   17.60000    0  132          -   17.60000      -     -   32s
#      0     0   17.60000    0  185          -   17.60000      -     -   32s
#      0     0   17.60000    0  176          -   17.60000      -     -   32s
#      0     0   17.60000    0  217          -   17.60000      -     -   33s
#      0     0   17.60000    0  257          -   17.60000      -     -   33s
#      0     0   17.60000    0  235          -   17.60000      -     -   33s
#      0     0   17.60000    0  132          -   17.60000      -     -   34s
#      0     2   17.60000    0  132          -   17.60000      -     -   36s
#   1040  1175   24.40000   89   84          -   17.60000      -  40.9   40s
#   2820  2617   19.10000   50  328          -   17.60000      -  31.9   53s
#   2821  2618   20.20000   50  212          -   17.60000      -  31.9   57s
#   2823  2619   36.50000  125  221          -   17.60000      -  31.9   61s
#   2825  2621   32.00000   48  251          -   17.60000      -  31.9   66s
#   2827  2622   19.60000   39  261          -   17.60000      -  31.8   79s
#   2829  2623   26.20000   45  228          -   17.60000      -  31.8   83s
#   2831  2625   23.00000   45  287          -   17.60000      -  31.8   86s
#   2833  2626   17.60000   54  162          -   17.60000      -  31.8   91s
#   2837  2629   17.60000   45  228          -   17.60000      -  31.7   97s
#   2839  2630   25.50000   33  472          -   17.60000      -  31.7  105s
#   2842  2635   17.60000   16  473          -   17.60000      -   105  112s
#   2856  2652   21.40000   19  583          -   17.60000      -   106  115s
#   2957  2729   22.70000   24  575          -   17.60000      -   105  120s
#   3527  3284   21.40000   39  535          -   17.60000      -  97.4  126s
#   4121  4020   21.40000   55  722          -   17.60000      -  93.8  132s
#   5669  5300   21.40000  127  881          -   17.60000      -  78.7  137s
#   6887  5717   21.40000  183  554          -   17.60000      -  69.8  140s
# H 7806  5674                    41274.000000   17.60000   100%  66.7  143s
# H 8166  6089                      59.1000000   17.60000  70.2%  66.3  145s
# H 8314  5921                      56.7000000   17.60000  69.0%  65.6  145s
# H 8345  5798                      53.2000000   17.60000  66.9%  65.6  145s
# H 8550  5622                      51.4000000   17.60000  65.8%  64.4  145s
# H 8788  5491                      51.1000000   17.60000  65.6%  62.9  145s
# H 8885  6227                      49.8000000   17.60000  64.7%  62.3  148s
# H 9154  6227                      47.5000000   17.60000  62.9%  61.1  148s
# H 9703  7427                      47.0000000   17.60000  62.6%  58.3  152s
#  11033  8361   29.10000  105  272   47.00000   17.60000  62.6%  53.4  155s
# H11443  8347                      46.5000000   17.60000  62.2%  52.3  155s
# H12341  9046                      46.5000000   17.60000  62.2%  49.9  158s
# H12661  9013                      46.1000000   17.60000  61.8%  49.4  158s
#  12726  9740   29.10000  155  267   46.10000   17.60000  61.8%  49.5  162s
# H13505  9598                      45.2000000   17.60000  61.1%  48.6  162s
#  13589 10349 infeasible  201        45.20000   17.60000  61.1%  48.5  166s
# H13987 10126                      44.3000000   17.60000  60.3%  48.2  166s
# H14403  9218                      40.5000000   17.60000  56.5%  47.9  169s
#  14622  9392     cutoff  207        40.50000   17.60000  56.5%  47.8  172s
# H14630  9355                      39.7000000   17.60000  55.7%  47.8  172s
# H14631  9320                      39.0000000   17.60000  54.9%  47.8  172s
#  14862  9591   29.10000   99  488   39.00000   17.60000  54.9%  47.7  176s
# H14863  9581                      38.7000000   17.60000  54.5%  47.7  176s
# H14997  9579                      38.4000000   17.60000  54.2%  47.9  176s
#  15162 10271   37.40000  125  376   38.40000   17.60000  54.2%  47.7  180s
# H15416 10163                      37.8000000   17.60000  53.4%  47.4  180s
#
# Cutting planes:
#   Cover: 178
#   Implied bound: 4
#   MIR: 1
#   Flow cover: 100
#   RLT: 97
#
# Explored 15898 nodes (1005331 simplex iterations) in 180.10 seconds (281.42 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 37.8 38.4 38.7 ... 46.5
#
# Time limit reached
# Best objective 3.780000000000e+01, best bound 1.760000000001e+01, gap 53.4392%
# ----------------
# file: instance 1.csv
# number of tardy jobs: 3.0
# makespan: 16.799999999997453
# ----------------
# ----------------
# file: instance 2.csv
# number of tardy jobs: 60.0
# makespan: 41.09999999999036
# ----------------
# ----------------
# file: instance 3.csv
# number of tardy jobs: 7.0
# makespan: 25.299999994738954
# ----------------
# ----------------
# file: instance 4.csv
# number of tardy jobs: 0.0
# makespan: 9.399999999999864
# ----------------
# ----------------
# file: instance 5.csv
# number of tardy jobs: 21.0
# makespan: 37.79999999999542
# ----------------

# %%
tardy_list = []
makespan_list = []

for path in path_list:
    df, machine_set, dummyM1_col, dummyM2_col = file_preprocess(path)
    tardy, makespan = IP(df, machine_set, dummyM1_col, dummyM2_col, 90, 270)
    tardy_list.append(tardy)
    makespan_list.append(makespan)
    print("----------------")
    print("file:", path)
    print("number of tardy jobs:", tardy)
    print("makespan:", makespan)
    print("----------------")
# Out:
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 9375 rows, 5130 columns and 28095 nonzeros
# Model fingerprint: 0x6a9a2da8
# Variable types: 615 continuous, 4515 integer (4515 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2729 rows and 1337 columns
# Presolve time: 0.05s
# Presolved: 6646 rows, 3793 columns, 20121 nonzeros
# Variable types: 476 continuous, 3317 integer (3317 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 5.664488e-04, 850 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00057    0   24   14.00000    0.00057   100%     -    0s
#      0     0    2.00009    0   45   14.00000    2.00009  85.7%     -    0s
# H    0     0                       3.0000000    2.00009  33.3%     -    0s
#      0     0    3.00000    0   49    3.00000    3.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Flow cover: 10
#   RLT: 5
#
# Explored 1 nodes (2229 simplex iterations) in 0.19 seconds (0.19 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 3 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Set parameter TimeLimit to value 270
# 15
# 2
# 10
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 9391 rows, 5131 columns and 28140 nonzeros
# Model fingerprint: 0xc2220a52
# Variable types: 616 continuous, 4515 integer (4515 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2694 rows and 1302 columns
# Presolve time: 0.04s
# Presolved: 6697 rows, 3829 columns, 20334 nonzeros
# Variable types: 512 continuous, 3317 integer (3317 binary)
#
# Root relaxation: objective 1.680000e+01, 1325 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.80000    0   31          -   16.80000      -     -    0s
#      0     0   16.80000    0   31          -   16.80000      -     -    0s
#      0     0   16.80000    0   32          -   16.80000      -     -    0s
#      0     0   16.80000    0   37          -   16.80000      -     -    0s
#      0     0   16.80000    0   34          -   16.80000      -     -    0s
# H    0     0                      26.0000000   16.80000  35.4%     -    0s
# H    0     0                      20.4000000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   18   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   18   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   23   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   21   20.40000   16.80000  17.6%     -    0s
# H    0     0                      19.7000000   16.80000  14.7%     -    0s
#      0     0   16.80000    0    7   19.70000   16.80000  14.7%     -    0s
# H    0     0                      18.7000000   16.80000  10.2%     -    0s
#      0     0   16.80000    0    8   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   10   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   12   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   12   18.70000   16.80000  10.2%     -    1s
#      0     2   16.80000    0   10   18.70000   16.80000  10.2%     -    1s
# H   44    42                      18.5000000   16.80000  9.19%  40.4    1s
# H  213   255                      18.2000000   16.80000  7.69%  21.3    1s
# H  601   511                      18.0000000   16.80000  6.67%  15.8    1s
# H  884   831                      17.9000000   16.80000  6.15%  14.9    1s
# * 1311   831              92      17.7000000   16.80000  5.08%  14.3    1s
# H 1313   831                      17.0000000   16.80000  1.18%  14.3    1s
# H 1586   701                      16.8000000   16.80000  0.00%  13.9    1s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 4
#   Implied bound: 43
#   MIR: 9
#   Flow cover: 99
#   Inf proof: 3
#   RLT: 16
#   Relax-and-lift: 3
#
# Explored 1963 nodes (43360 simplex iterations) in 1.99 seconds (1.83 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 16.8 17 17.7 ... 20.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.680000000000e+01, best bound 1.680000000000e+01, gap 0.0000%
# ----------------
# file: instance 1.csv
# number of tardy jobs: 3.0
# makespan: 16.799999999997453
# ----------------
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 255407 rows, 130784 columns and 766526 nonzeros
# Model fingerprint: 0x91304890
# Variable types: 4209 continuous, 126575 integer (126575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 50583 rows and 24884 columns
# Presolve time: 1.37s
# Presolved: 204824 rows, 105900 columns, 616423 nonzeros
# Variable types: 3461 continuous, 102439 integer (102439 binary)
# Found heuristic solution: objective 60.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 1222 rows and 287 columns
# Root relaxation presolved: 203602 rows, 106548 columns, 613979 nonzeros
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 4.970499e-04, 9555 iterations, 0.80 seconds (0.92 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00050    0 6199   60.00000    0.00050   100%     -    7s
#      0     0    3.00046    0 2783   60.00000    3.00046  95.0%     -   12s
#      0     0    5.00022    0 1505   60.00000    5.00022  91.7%     -   15s
#      0     0    5.00027    0 1457   60.00000    5.00027  91.7%     -   16s
#      0     0    5.00027    0 2076   60.00000    5.00027  91.7%     -   21s
#      0     0    5.00028    0 2119   60.00000    5.00028  91.7%     -   29s
#      0     0    5.00028    0 1910   60.00000    5.00028  91.7%     -   58s
#      0     0    5.00028    0 1599   60.00000    5.00028  91.7%     -   71s
#      0     0    5.00036    0 1955   60.00000    5.00036  91.7%     -   88s
#      0     0          -    0        60.00000    5.00036  91.7%     -   90s
#
# Cutting planes:
#   Cover: 570
#   MIR: 6
#   Flow cover: 356
#   GUB cover: 1
#   Zero half: 1
#   Network: 5
#   RLT: 502
#
# Explored 1 nodes (177153 simplex iterations) in 90.01 seconds (464.15 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 60
#
# Time limit reached
# Best objective 6.000000000000e+01, best bound 6.000000000000e+00, gap 90.0000%
# Set parameter TimeLimit to value 270
# 61
# 2
# 17
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 255469 rows, 130785 columns and 766709 nonzeros
# Model fingerprint: 0x7ee113d2
# Variable types: 4210 continuous, 126575 integer (126575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 50335 rows and 24636 columns
# Presolve time: 1.45s
# Presolved: 205134 rows, 106149 columns, 617889 nonzeros
# Variable types: 3710 continuous, 102439 integer (102439 binary)
# Found heuristic solution: objective 318.4000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 248 rows and 237 columns
# Root relaxation presolved: 204886 rows, 105912 columns, 617041 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.04s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 1.840000e+01, 7623 iterations, 1.04 seconds (1.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.40000    0 15206  318.40000   18.40000  94.2%     -    9s
# H    0     0                     158.1000000   18.40000  88.4%     -   10s
#      0     0   18.40000    0 2535  158.10000   18.40000  88.4%     -   25s
#      0     0   18.40000    0 1807  158.10000   18.40000  88.4%     -   32s
#      0     0   18.40000    0 2674  158.10000   18.40000  88.4%     -   49s
#      0     0   18.40000    0 1916  158.10000   18.40000  88.4%     -   60s
