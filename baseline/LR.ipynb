# %%
from gurobipy import *
import pandas as pd
import numpy as np
import os

# display settings
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %% [markdown]
# ## Set mode

# %%
# mode = "train"
mode = "testcase"

# %% [markdown]
# ## Set working directory

# %%
print(os.getcwd())

if mode == "train":
    if (os.getcwd() == "/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/to students/data"):
        pass
    else:
        os.chdir("/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/to students/data")
else:
    if (os.getcwd() == "/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/testcase/testcases"):
        pass
    else:
        os.chdir("/Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/testcase/testcases")

print(os.getcwd())
os.listdir()
# Out:
# /Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/baseline
# /Users/wangyanpu/Desktop/台灣大學/大三下/作業研究/case/Case2/testcase/testcases
# ['instance 345.csv',
#  'instance 351.csv',
#  'instance 184.csv',
#  'instance 190.csv',
#  'instance 14.csv',
#  'instance 28.csv',
#  'instance 147.csv',
#  'instance 153.csv',
#  'instance 9.csv',
#  'instance 219.csv',
#  'instance 231.csv',
#  'instance 225.csv',
#  'instance 224.csv',
#  'instance 230.csv',
#  'instance 218.csv',
#  'instance 8.csv',
#  'instance 152.csv',
#  'instance 29.csv',
#  'instance 146.csv',
#  'instance 15.csv',
#  'instance 191.csv',
#  'instance 185.csv',
#  'instance 350.csv',
#  'instance 344.csv',
#  'instance 352.csv',
#  'instance 346.csv',
#  'instance 193.csv',
#  'instance 187.csv',
#  'instance 178.csv',
#  'instance 17.csv',
#  'instance 150.csv',
#  'instance 144.csv',
#  'instance 226.csv',
#  'instance 232.csv',
#  'instance 233.csv',
#  'instance 227.csv',
#  'instance 145.csv',
#  'instance 151.csv',
#  'instance 179.csv',
#  'instance 16.csv',
#  'instance 186.csv',
#  'instance 192.csv',
#  'instance 347.csv',
#  'instance 353.csv',
#  'instance 343.csv',
#  'instance 196.csv',
#  'instance 182.csv',
#  'instance 155.csv',
#  'instance 141.csv',
#  'instance 169.csv',
#  'instance 12.csv',
#  '.DS_Store',
#  'instance 223.csv',
#  'instance 237.csv',
#  'instance 236.csv',
#  'instance 222.csv',
#  'instance 13.csv',
#  'instance 168.csv',
#  'instance 140.csv',
#  'instance 154.csv',
#  'instance 183.csv',
#  'instance 197.csv',
#  'instance 342.csv',
#  'instance 340.csv',
#  'instance 354.csv',
#  'instance 181.csv',
#  'instance 195.csv',
#  'instance 142.csv',
#  'instance 39.csv',
#  'instance 156.csv',
#  'instance 11.csv',
#  'instance 234.csv',
#  'instance 220.csv',
#  'instance 208.csv',
#  'instance 209.csv',
#  'instance 221.csv',
#  'instance 235.csv',
#  'instance 10.csv',
#  'instance 38.csv',
#  'instance 157.csv',
#  'instance 143.csv',
#  'instance 194.csv',
#  'instance 180.csv',
#  'instance 341.csv',
#  'instance 326.csv',
#  'instance 332.csv',
#  'instance 88.csv',
#  'instance 118.csv',
#  'instance 77.csv',
#  'instance 63.csv',
#  'instance 124.csv',
#  'instance 130.csv',
#  'instance 291.csv',
#  'instance 285.csv',
#  'instance 252.csv',
#  'instance 246.csv',
#  'instance 247.csv',
#  'instance 253.csv',
#  'instance 284.csv',
#  'instance 290.csv',
#  'instance 131.csv',
#  'instance 125.csv',
#  'instance 62.csv',
#  'instance 119.csv',
#  'instance 76.csv',
#  'instance 89.csv',
#  'instance 333.csv',
#  'instance 327.csv',
#  'instance 319.csv',
#  'instance 331.csv',
#  'instance 325.csv',
#  'instance 60.csv',
#  'instance 74.csv',
#  'instance 133.csv',
#  'instance 48.csv',
#  'instance 127.csv',
#  'instance 286.csv',
#  'instance 292.csv',
#  'instance 279.csv',
#  'instance 245.csv',
#  'instance 251.csv',
#  'instance 250.csv',
#  'instance 244.csv',
#  'instance 278.csv',
#  'instance 293.csv',
#  'instance 287.csv',
#  'instance 49.csv',
#  'instance 126.csv',
#  'instance 132.csv',
#  'instance 75.csv',
#  'instance 61.csv',
#  'instance 324.csv',
#  'instance 330.csv',
#  'instance 318.csv',
#  'instance 334.csv',
#  'instance 320.csv',
#  'instance 308.csv',
#  'instance 59.csv',
#  'instance 136.csv',
#  'instance 122.csv',
#  'instance 65.csv',
#  'instance 71.csv',
#  'instance 283.csv',
#  'instance 297.csv',
#  'instance 240.csv',
#  'instance 254.csv',
#  'instance 268.csv',
#  'instance 269.csv',
#  'instance 255.csv',
#  'instance 241.csv',
#  'instance 296.csv',
#  'instance 282.csv',
#  'instance 70.csv',
#  'instance 64.csv',
#  'instance 123.csv',
#  'instance 58.csv',
#  'instance 137.csv',
#  'instance 309.csv',
#  'instance 321.csv',
#  'instance 335.csv',
#  'instance 323.csv',
#  'instance 337.csv',
#  'instance 99.csv',
#  'instance 121.csv',
#  'instance 135.csv',
#  'instance 72.csv',
#  'instance 109.csv',
#  'instance 66.csv',
#  'instance 294.csv',
#  'instance 280.csv',
#  'instance 257.csv',
#  'instance 243.csv',
#  'instance 242.csv',
#  'instance 256.csv',
#  'instance 281.csv',
#  'instance 295.csv',
#  'instance 108.csv',
#  'instance 67.csv',
#  'instance 73.csv',
#  'instance 134.csv',
#  'instance 120.csv',
#  'instance 98.csv',
#  'instance 336.csv',
#  'instance 322.csv',
#  'instance 307.csv',
#  'instance 313.csv',
#  'instance 95.csv',
#  'instance 81.csv',
#  'instance 139.csv',
#  'instance 56.csv',
#  'instance 42.csv',
#  'instance 105.csv',
#  'instance 111.csv',
#  'instance 298.csv',
#  'instance 273.csv',
#  'instance 267.csv',
#  'instance 266.csv',
#  'instance 272.csv',
#  'instance 299.csv',
#  'instance 110.csv',
#  'instance 104.csv',
#  'instance 43.csv',
#  'instance 138.csv',
#  'instance 57.csv',
#  'instance 80.csv',
#  'instance 94.csv',
#  'instance 312.csv',
#  'instance 306.csv',
#  'instance 338.csv',
#  'instance 310.csv',
#  'instance 304.csv',
#  'instance 82.csv',
#  'instance 96.csv',
#  'instance 41.csv',
#  'instance 55.csv',
#  'instance 112.csv',
#  'instance 69.csv',
#  'instance 106.csv',
#  'instance 258.csv',
#  'instance 264.csv',
#  'instance 270.csv',
#  'instance 271.csv',
#  'instance 265.csv',
#  'instance 259.csv',
#  'instance 68.csv',
#  'instance 107.csv',
#  'instance 113.csv',
#  'instance 54.csv',
#  'instance 40.csv',
#  'instance 97.csv',
#  'instance 83.csv',
#  'instance 305.csv',
#  'instance 311.csv',
#  'instance 339.csv',
#  'instance 315.csv',
#  'instance 301.csv',
#  'instance 329.csv',
#  'instance 87.csv',
#  'instance 93.csv',
#  'instance 78.csv',
#  'instance 117.csv',
#  'instance 103.csv',
#  'instance 44.csv',
#  'instance 50.csv',
#  'instance 261.csv',
#  'instance 275.csv',
#  'instance 249.csv',
#  'instance 248.csv',
#  'instance 274.csv',
#  'instance 260.csv',
#  'instance 51.csv',
#  'instance 45.csv',
#  'instance 102.csv',
#  'instance 79.csv',
#  'instance 116.csv',
#  'instance 92.csv',
#  'instance 86.csv',
#  'instance 328.csv',
#  'instance 300.csv',
#  'instance 314.csv',
#  'instance 302.csv',
#  'instance 316.csv',
#  'instance 90.csv',
#  'instance 84.csv',
#  'instance 100.csv',
#  'instance 114.csv',
#  'instance 53.csv',
#  'instance 128.csv',
#  'instance 47.csv',
#  'instance 289.csv',
#  'instance 276.csv',
#  'instance 262.csv',
#  'instance 263.csv',
#  'instance 277.csv',
#  'instance 288.csv',
#  'instance 129.csv',
#  'instance 46.csv',
#  'instance 52.csv',
#  'instance 115.csv',
#  'instance 101.csv',
#  'instance 85.csv',
#  'instance 91.csv',
#  'instance 317.csv',
#  'instance 303.csv',
#  'instance 199.csv',
#  'instance 35.csv',
#  'instance 21.csv',
#  'instance 166.csv',
#  'instance 172.csv',
#  'instance 238.csv',
#  'instance 210.csv',
#  'instance 204.csv',
#  'instance 205.csv',
#  'instance 211.csv',
#  'instance 239.csv',
#  'instance 1.csv',
#  'instance 173.csv',
#  'instance 167.csv',
#  'instance 20.csv',
#  'instance 34.csv',
#  'instance 198.csv',
#  'instance 22.csv',
#  'instance 159.csv',
#  'instance 36.csv',
#  'instance 171.csv',
#  'instance 165.csv',
#  'instance 3.csv',
#  'instance 207.csv',
#  'instance 213.csv',
#  'instance 212.csv',
#  'instance 206.csv',
#  'instance 2.csv',
#  'instance 164.csv',
#  'instance 170.csv',
#  'instance 158.csv',
#  'instance 37.csv',
#  'instance 23.csv',
#  'instance 174.csv',
#  'instance 160.csv',
#  'instance 148.csv',
#  'instance 27.csv',
#  'instance 33.csv',
#  'instance 6.csv',
#  'instance 202.csv',
#  'instance 216.csv',
#  'instance 217.csv',
#  'instance 203.csv',
#  'instance 7.csv',
#  'instance 32.csv',
#  'instance 149.csv',
#  'instance 26.csv',
#  'instance 161.csv',
#  'instance 175.csv',
#  'instance 349.csv',
#  'instance 188.csv',
#  'instance 163.csv',
#  'instance 18.csv',
#  'instance 177.csv',
#  'instance 30.csv',
#  'instance 24.csv',
#  'instance 5.csv',
#  'instance 215.csv',
#  'instance 201.csv',
#  'instance 229.csv',
#  'instance 228.csv',
#  'instance 200.csv',
#  'instance 214.csv',
#  'instance 4.csv',
#  'instance 25.csv',
#  'instance 31.csv',
#  'instance 19.csv',
#  'instance 176.csv',
#  'instance 162.csv',
#  'instance 189.csv',
#  'instance 348.csv']

# %% [markdown]
# ## Defining Functions

# %%
def split_(row, machine_set):
    if row is np.nan:
        return list(machine_set)
    else:
        return list(map(int, row.split(",")))

# %%
def file_preprocess(file_path):
    ''' read csv and create usable dataframe'''
    
    # get machine set
    df = pd.read_csv(file_path, index_col=0)
    mfor1 = df['Stage-1 Machines'].values
    mfor2 = df['Stage-2 Machines'].values
    mfor1 = [list(map(int, x.split(','))) for x in mfor1]
    mfor2 = [list(map(int, x.split(','))) for x in mfor2 if x is not np.nan]
    mfor1 = [item for sublist in mfor1 for item in sublist]
    mfor2 = [item for sublist in mfor2 for item in sublist]
    machine_set_ = list(set(mfor1 + mfor2))
    
    # turn strings into list in dataframe
    df["Stage-1 Machines"] = df["Stage-1 Machines"].apply(split_, machine_set=machine_set_)
    df["Stage-2 Machines"] = df["Stage-2 Machines"].apply(split_, machine_set=machine_set_)
    
    from sklearn.preprocessing import MultiLabelBinarizer
    stage1 = df["Stage-1 Machines"]
    stage2 = df["Stage-2 Machines"]

    # create stage machine dummy variables from list
    mlb = MultiLabelBinarizer()
    mlb2 = MultiLabelBinarizer()
    dummyM1_df = pd.DataFrame(mlb.fit_transform(stage1), columns=mlb.classes_, index=df.index)
    dummyM1_df = dummyM1_df.add_prefix("stage1_m")
    dummyM2_df = pd.DataFrame(mlb2.fit_transform(stage2), columns=mlb2.classes_, index=df.index)
    dummyM2_df = dummyM2_df.add_prefix("stage2_m")
    dummyM1_df, dummyM2_df
    
    # dummy column names
    dummyM1_col = dummyM1_df.columns
    dummyM2_col = dummyM2_df.columns

    df = df.join(dummyM1_df, on="Job ID")
    df = df.join(dummyM2_df, on="Job ID")
    df = df.drop(["Stage-1 Machines", "Stage-2 Machines"], axis=1)
    
    return df, machine_set_, dummyM1_col, dummyM2_col

# %%
def IP(instance, machine_set, dummyM1_col, dummyM2_col, time_limit1, time_limit2):
    ''' two stage optimization'''
    
    # turn data into corresponding list
    pt_stage1 = instance["Stage-1 Processing Time"].values
    pt_stage2 = instance["Stage-2 Processing Time"].values
    due_time = instance["Due Time"].values

    job_id = list(instance.index)
    m_dummy_stage1 = instance[dummyM1_col].values
    m_dummy_stage2 = instance[dummyM2_col].values
    
    # L: big number
    L = (sum(pt_stage1) + sum(pt_stage2)) * 100
    
    ''' stage 1 '''
    p1 = Model("p1")
    p1.setParam('TimeLimit', time_limit1)
    j_num = int(len(job_id))
    m_len = len(machine_set)

    # Variables
    s_jkm = []
    c_jkm = []
    x_jkm = []
    for j in range(j_num):
        tmp_s = []
        tmp_c = []
        tmp_x = []
        for k in range(2):
            tmp_s.append([])
            tmp_c.append([])
            tmp_x.append([])
            for m in machine_set:
                tmp_s[k].append(p1.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "s_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_c[k].append(p1.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_x[k].append(p1.addVar(lb = 0, vtype = GRB.BINARY, name = "x_" + str(j + 1) + "," + str(k) + ","+ str(m)))  
        s_jkm.append(tmp_s)
        c_jkm.append(tmp_c)
        x_jkm.append(tmp_x)

    y_jkjkm = []
    for j1 in range(j_num):
        y_jkjkm.append([])
        for k1 in range(2):
            y_jkjkm[j1].append([])
            for j2 in range(j1 + 1, j_num):
                y_jkjkm[j1][k1].append([])
                for k2 in range(2):
                    y_jkjkm[j1][k1][j2 - j1 - 1].append([])
                    for m in machine_set:
                        y_jkjkm[j1][k1][j2 - j1 - 1][k2].append(p1.addVar(lb = 0, vtype = GRB.BINARY, 
                                                       name = "y_" + str(j1 + 1) + "," + str(k1 + 1) + "," + str(j2 + 1) + "," + str(k2 + 1)+ "," + str(m)))

    c_j = []
    for j in range(j_num):
        c_j.append(p1.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1)))
    t_j = []
    for j in range(j_num):
        t_j.append(p1.addVar(lb = 0, vtype = GRB.BINARY, name = "t_" + str(j + 1)))
        
    # setting the objective function 
    p1.setObjective(quicksum(t_j[j] for j in range(j_num)), GRB.MINIMIZE) 
    
    # add constraints
    # job stage 1 machine limit
    p1.addConstrs((x_jkm[j][0][m] <= m_dummy_stage1[j][m] for j in range(j_num) for m in range(m_len)))
    # job stage 2 machine limit
    p1.addConstrs((x_jkm[j][1][m] <= m_dummy_stage2[j][m] for j in range(j_num) for m in range(m_len)))

    # tardy variable
    p1.addConstrs((t_j[j] * L >= c_j[j] - due_time[j] 
                    for j in range(j_num)), "tardy count")

    # job complete time
    p1.addConstrs((c_j[j] >= quicksum(c_jkm[j][1][m] for m in range(m_len))
                    for j in range(j_num)), "job completion time")

    # each job assigned once
    p1.addConstrs((quicksum(x_jkm[j][k][m] for m in range(m_len)) == 1 for j in range(j_num) for k in range(2)), "job assignment constraint")

    p1.addConstrs((s_jkm[j][k][m] + c_jkm[j][k][m] <= x_jkm[j][k][m] * L for j in range(j_num) for k in range(2) for m in range(m_len)))

    # process time
    p1.addConstrs((c_jkm[j][0][m] >= s_jkm[j][0][m] + pt_stage1[j] - (1 - x_jkm[j][0][m]) * L for j in range(j_num) for m in range(m_len)))
    p1.addConstrs((c_jkm[j][1][m] >= s_jkm[j][1][m] + pt_stage2[j] - (1 - x_jkm[j][1][m]) * L for j in range(j_num) for m in range(m_len)))

    for m in range(m_len):
        for j1 in range(j_num):
            for k1 in range(2):
                for j2 in range(j_num - j1 - 1):
                    for k2 in range(2):
                    # 注意ijm的indexing方法不同
                        p1.addConstr(s_jkm[j1][k1][m] >= c_jkm[j1 + j2 + 1][k2][m] - y_jkjkm[j1][k1][j2][k2][m] * L)
                        p1.addConstr(s_jkm[j1 + j2 + 1][k2][m] >= c_jkm[j1][k1][m] - (1 - y_jkjkm[j1][k1][j2][k2][m]) * L)

    # subjob 2 starts only after subjob 1
    p1.addConstrs((quicksum(s_jkm[j][1][m] for m in range(m_len)) >= quicksum(c_jkm[j][0][m] for m in range(m_len)) for j in range(j_num)), "subjob 1 ends before subjob2 starts")
    
    r1 = p1.relax()
    r1.optimize()
    
    
    ''' stage 2 '''
    p1_2 = Model("p1_2")
    
    # set time limit
    p1_2.setParam('TimeLimit', time_limit2)
    j_num = int(len(job_id))
    m_len = len(machine_set)

    # tardy job num result from part 1
    T = r1.objVal

    # Variables
    u = p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "u")
    s_jkm = []
    c_jkm = []
    x_jkm = []
    for j in range(j_num):
        tmp_s = []
        tmp_c = []
        tmp_x = []
        for k in range(2):
            tmp_s.append([])
            tmp_c.append([])
            tmp_x.append([])
            for m in machine_set:
                tmp_s[k].append(p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "s_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_c[k].append(p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1) + "," + str(k + 1) + "," + str(m)))
                tmp_x[k].append(p1_2.addVar(lb = 0, vtype = GRB.BINARY, name = "x_" + str(j + 1) + "," + str(k) + ","+ str(m)))  
        s_jkm.append(tmp_s)
        c_jkm.append(tmp_c)
        x_jkm.append(tmp_x)
    print(len(x_jkm))
    print(len(x_jkm[0]))
    print(len(x_jkm[0][0]))

    y_jkjkm = []
    for j1 in range(j_num):
        y_jkjkm.append([])
        for k1 in range(2):
            y_jkjkm[j1].append([])
            for j2 in range(j1 + 1, j_num):
                y_jkjkm[j1][k1].append([])
                for k2 in range(2):
                    y_jkjkm[j1][k1][j2 - j1 - 1].append([])
                    for m in machine_set:
                        y_jkjkm[j1][k1][j2 - j1 - 1][k2].append(p1_2.addVar(lb = 0, vtype = GRB.BINARY, 
                                                       name = "y_" + str(j1 + 1) + "," + str(k1 + 1) + "," + str(j2 + 1) + "," + str(k2 + 1)+ "," + str(m)))

    c_j = []
    for j in range(j_num):
        c_j.append(p1_2.addVar(lb = 0, vtype = GRB.CONTINUOUS, name = "c_" + str(j + 1)))
    t_j = []
    for j in range(j_num):
        t_j.append(p1_2.addVar(lb = 0, vtype = GRB.BINARY, name = "t_" + str(j + 1)))
        
        
    # setting the objective function 
    p1_2.setObjective(u, GRB.MINIMIZE) 
    
    
    # add constraints and name them
    # makespan
    p1_2.addConstrs((u >= c_j[j] for j in range(j_num)))
    
    # tardy jobs num set to "lesser than or equal to" T
    p1_2.addConstr((quicksum(t_j[j] for j in range(j_num)) <= T))

    # stage 1 machine limit
    p1_2.addConstrs((x_jkm[j][0][m] <= m_dummy_stage1[j][m] for j in range(j_num) for m in range(m_len)))
    # stage 2 machine limit
    p1_2.addConstrs((x_jkm[j][1][m] <= m_dummy_stage2[j][m] for j in range(j_num) for m in range(m_len)))

    # tardy variable
    p1_2.addConstrs((t_j[j] * L >= c_j[j] - due_time[j] 
                    for j in range(j_num)), "tardy count")

    # job complete time
    p1_2.addConstrs((c_j[j] >= quicksum(c_jkm[j][1][m] for m in range(m_len))
                    for j in range(j_num)), "job completion time")

    # each job assigned once
    p1_2.addConstrs((quicksum(x_jkm[j][k][m] for m in range(m_len)) == 1 for j in range(j_num) for k in range(2)), "job assignment constraint")

    p1_2.addConstrs((s_jkm[j][k][m] + c_jkm[j][k][m] <= x_jkm[j][k][m] * L for j in range(j_num) for k in range(2) for m in range(m_len)))

    # process time
    p1_2.addConstrs((c_jkm[j][0][m] >= s_jkm[j][0][m] + pt_stage1[j] - (1 - x_jkm[j][0][m]) * L for j in range(j_num) for m in range(m_len)))
    p1_2.addConstrs((c_jkm[j][1][m] >= s_jkm[j][1][m] + pt_stage2[j] - (1 - x_jkm[j][1][m]) * L for j in range(j_num) for m in range(m_len)))

    for m in range(m_len):
        for j1 in range(j_num):
            for k1 in range(2):
                for j2 in range(j_num - j1 - 1):
                    for k2 in range(2):
                    # 注意ijm的indexing方法不同
                        p1_2.addConstr(s_jkm[j1][k1][m] >= c_jkm[j1 + j2 + 1][k2][m] - y_jkjkm[j1][k1][j2][k2][m] * L)
                        p1_2.addConstr(s_jkm[j1 + j2 + 1][k2][m] >= c_jkm[j1][k1][m] - (1 - y_jkjkm[j1][k1][j2][k2][m]) * L)

    # subjob 2 starts only after subjob 1
    p1_2.addConstrs((quicksum(s_jkm[j][1][m] for m in range(m_len)) >= quicksum(c_jkm[j][0][m] for m in range(m_len)) for j in range(j_num)), "subjob 1 ends before subjob2 starts")
    
    r1_2 = p1_2.relax()
    r1_2.optimize()
    
    
    return r1.objVal, r1_2.objVal

# %% [markdown]
# ## Set instances and test

# %%
# set instances to test
path_list = ["instance 1.csv", "instance 2.csv", "instance 3.csv", "instance 4.csv", "instance 5.csv"]
# path_list = ["instance 5.csv"]

# %%
tardy_list = []
makespan_list = []

for path in path_list:
    df, machine_set, dummyM1_col, dummyM2_col = file_preprocess(path)
    tardy, makespan = IP(df, machine_set, dummyM1_col, dummyM2_col, 60, 180)
    tardy_list.append(tardy)
    makespan_list.append(makespan)

for i in range(len(path_list)):
    print("----------------")
    print("file:", path_list[i])
    print("number of tardy jobs:", tardy_list[i])
    print("makespan:", makespan_list[i])
    print("----------------")
# Out:
# Set parameter TimeLimit to value 60
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 180
# 15
# 2
# 10
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 60
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 180
# 61
# 2
# 17
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 60
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 180
# 22
# 2
# 8
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 60
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 180
# 2
# 2
# 13
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 60
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Set parameter TimeLimit to value 180
# 42
# 2
# 13
# Warning: model has pending changes.
# Derived model does not contain these changes.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 0 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0xf9715da1
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ----------------
# file: instance 1.csv
# number of tardy jobs: 0.0
# makespan: 0.0
# ----------------
# ----------------
# file: instance 2.csv
# number of tardy jobs: 0.0
# makespan: 0.0
# ----------------
# ----------------
# file: instance 3.csv
# number of tardy jobs: 0.0
# makespan: 0.0
# ----------------
# ----------------
# file: instance 4.csv
# number of tardy jobs: 0.0
# makespan: 0.0
# ----------------
# ----------------
# file: instance 5.csv
# number of tardy jobs: 0.0
# makespan: 0.0
# ----------------

# %%
tardy_list = []
makespan_list = []

for path in path_list:
    df, machine_set, dummyM1_col, dummyM2_col = file_preprocess(path)
    tardy, makespan = IP(df, machine_set, dummyM1_col, dummyM2_col, 90, 270)
    tardy_list.append(tardy)
    makespan_list.append(makespan)
    print("----------------")
    print("file:", path)
    print("number of tardy jobs:", tardy)
    print("makespan:", makespan)
    print("----------------")
# Out:
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 9375 rows, 5130 columns and 28095 nonzeros
# Model fingerprint: 0x6a9a2da8
# Variable types: 615 continuous, 4515 integer (4515 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2729 rows and 1337 columns
# Presolve time: 0.05s
# Presolved: 6646 rows, 3793 columns, 20121 nonzeros
# Variable types: 476 continuous, 3317 integer (3317 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 5.664488e-04, 850 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00057    0   24   14.00000    0.00057   100%     -    0s
#      0     0    2.00009    0   45   14.00000    2.00009  85.7%     -    0s
# H    0     0                       3.0000000    2.00009  33.3%     -    0s
#      0     0    3.00000    0   49    3.00000    3.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Flow cover: 10
#   RLT: 5
#
# Explored 1 nodes (2229 simplex iterations) in 0.19 seconds (0.19 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 3 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Set parameter TimeLimit to value 270
# 15
# 2
# 10
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 9391 rows, 5131 columns and 28140 nonzeros
# Model fingerprint: 0xc2220a52
# Variable types: 616 continuous, 4515 integer (4515 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2694 rows and 1302 columns
# Presolve time: 0.04s
# Presolved: 6697 rows, 3829 columns, 20334 nonzeros
# Variable types: 512 continuous, 3317 integer (3317 binary)
#
# Root relaxation: objective 1.680000e+01, 1325 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.80000    0   31          -   16.80000      -     -    0s
#      0     0   16.80000    0   31          -   16.80000      -     -    0s
#      0     0   16.80000    0   32          -   16.80000      -     -    0s
#      0     0   16.80000    0   37          -   16.80000      -     -    0s
#      0     0   16.80000    0   34          -   16.80000      -     -    0s
# H    0     0                      26.0000000   16.80000  35.4%     -    0s
# H    0     0                      20.4000000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   18   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   18   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   23   20.40000   16.80000  17.6%     -    0s
#      0     0   16.80000    0   21   20.40000   16.80000  17.6%     -    0s
# H    0     0                      19.7000000   16.80000  14.7%     -    0s
#      0     0   16.80000    0    7   19.70000   16.80000  14.7%     -    0s
# H    0     0                      18.7000000   16.80000  10.2%     -    0s
#      0     0   16.80000    0    8   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   10   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   12   18.70000   16.80000  10.2%     -    0s
#      0     0   16.80000    0   12   18.70000   16.80000  10.2%     -    1s
#      0     2   16.80000    0   10   18.70000   16.80000  10.2%     -    1s
# H   44    42                      18.5000000   16.80000  9.19%  40.4    1s
# H  213   255                      18.2000000   16.80000  7.69%  21.3    1s
# H  601   511                      18.0000000   16.80000  6.67%  15.8    1s
# H  884   831                      17.9000000   16.80000  6.15%  14.9    1s
# * 1311   831              92      17.7000000   16.80000  5.08%  14.3    1s
# H 1313   831                      17.0000000   16.80000  1.18%  14.3    1s
# H 1586   701                      16.8000000   16.80000  0.00%  13.9    1s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 4
#   Implied bound: 43
#   MIR: 9
#   Flow cover: 99
#   Inf proof: 3
#   RLT: 16
#   Relax-and-lift: 3
#
# Explored 1963 nodes (43360 simplex iterations) in 1.99 seconds (1.83 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 16.8 17 17.7 ... 20.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.680000000000e+01, best bound 1.680000000000e+01, gap 0.0000%
# ----------------
# file: instance 1.csv
# number of tardy jobs: 3.0
# makespan: 16.799999999997453
# ----------------
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 255407 rows, 130784 columns and 766526 nonzeros
# Model fingerprint: 0x91304890
# Variable types: 4209 continuous, 126575 integer (126575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 50583 rows and 24884 columns
# Presolve time: 1.37s
# Presolved: 204824 rows, 105900 columns, 616423 nonzeros
# Variable types: 3461 continuous, 102439 integer (102439 binary)
# Found heuristic solution: objective 60.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 1222 rows and 287 columns
# Root relaxation presolved: 203602 rows, 106548 columns, 613979 nonzeros
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 4.970499e-04, 9555 iterations, 0.80 seconds (0.92 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00050    0 6199   60.00000    0.00050   100%     -    7s
#      0     0    3.00046    0 2783   60.00000    3.00046  95.0%     -   12s
#      0     0    5.00022    0 1505   60.00000    5.00022  91.7%     -   15s
#      0     0    5.00027    0 1457   60.00000    5.00027  91.7%     -   16s
#      0     0    5.00027    0 2076   60.00000    5.00027  91.7%     -   21s
#      0     0    5.00028    0 2119   60.00000    5.00028  91.7%     -   29s
#      0     0    5.00028    0 1910   60.00000    5.00028  91.7%     -   58s
#      0     0    5.00028    0 1599   60.00000    5.00028  91.7%     -   71s
#      0     0    5.00036    0 1955   60.00000    5.00036  91.7%     -   88s
#      0     0          -    0        60.00000    5.00036  91.7%     -   90s
#
# Cutting planes:
#   Cover: 570
#   MIR: 6
#   Flow cover: 356
#   GUB cover: 1
#   Zero half: 1
#   Network: 5
#   RLT: 502
#
# Explored 1 nodes (177153 simplex iterations) in 90.01 seconds (464.15 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 60
#
# Time limit reached
# Best objective 6.000000000000e+01, best bound 6.000000000000e+00, gap 90.0000%
# Set parameter TimeLimit to value 270
# 61
# 2
# 17
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 255469 rows, 130785 columns and 766709 nonzeros
# Model fingerprint: 0x7ee113d2
# Variable types: 4210 continuous, 126575 integer (126575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 50335 rows and 24636 columns
# Presolve time: 1.45s
# Presolved: 205134 rows, 106149 columns, 617889 nonzeros
# Variable types: 3710 continuous, 102439 integer (102439 binary)
# Found heuristic solution: objective 318.4000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 248 rows and 237 columns
# Root relaxation presolved: 204886 rows, 105912 columns, 617041 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.04s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 1.840000e+01, 7623 iterations, 1.04 seconds (1.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.40000    0 15206  318.40000   18.40000  94.2%     -    9s
# H    0     0                     158.1000000   18.40000  88.4%     -   10s
#      0     0   18.40000    0 2535  158.10000   18.40000  88.4%     -   25s
#      0     0   18.40000    0 1807  158.10000   18.40000  88.4%     -   32s
#      0     0   18.40000    0 2674  158.10000   18.40000  88.4%     -   49s
#      0     0   18.40000    0 1916  158.10000   18.40000  88.4%     -   60s
